# %% [markdown]
# # Multiple Linear Regression (MLR) Models
# MLR models are created in this notebook using various input combinations.

# %% [markdown]
# ## To do:
# * Train using all feature combinations then explore data once
# * Add points in the plot_station_series graph for easier comparison between measured and predicted values

# %%
import os

# %%
# %run C:\Users\HP\Desktop\Git\evapotranspiration\part_3\functions\MLR_class.ipynb
# %run C:\Users\HP\Desktop\Git\evapotranspiration\part_3\functions\MyModel.ipynb

# %% [markdown]
# Define paths to data and models

# %%
# Path to the directory where the models are to be saved
save_path = r"C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR"

# Path to the directory where the data is saved
data_path = r'C:\Users\HP\Desktop\Git\evapotranspiration\processed_data'

# %% [markdown]
# Define regressor

# %%
name = 'mlr'
regressor = MLRRegressor

model_params = {}
fit_params = {}

# %%
for feature_combo in range(1, 15):
    model_name = '{}_{}'.format(name, feature_combo)
    
    print('\n')
    print('Model: {}'.format(model_name))
    print('\n')
    
    my_model =  MyModel(
                    model_name=model_name,
                    feature_combo=feature_combo,
                    regressor=regressor,
                    model_params=model_params,
                    fit_params=fit_params,
                    save_path=save_path,
                    data_path=data_path
                    )
    print('\n')
    
    my_model.fit_model()
    my_model.save()
    
    print('-'*25)
# Out:
# Model: mlr_1
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_1.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.438
# RMSE = 0.546
# R2 = 0.921
# WI = 0.868
#
#
# Test scores:
# MAE = 0.431
# RMSE = 0.533
# R2 = 0.887
# WI = 0.843
# -------------------------
#
#
# Model: mlr_2
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_2.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.438
# RMSE = 0.546
# R2 = 0.921
# WI = 0.868
#
#
# Test scores:
# MAE = 0.433
# RMSE = 0.534
# R2 = 0.886
# WI = 0.842
# -------------------------
#
#
# Model: mlr_3
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_3.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.911
# RMSE = 1.150
# R2 = 0.650
# WI = 0.726
#
#
# Test scores:
# MAE = 0.781
# RMSE = 0.943
# R2 = 0.645
# WI = 0.715
# -------------------------
#
#
# Model: mlr_4
#
#
# ...

# %%
my_model.plot_predictions(title='test')
# Out:
# <AxesSubplot:title={'center':'test'}, xlabel='Measured Values', ylabel='Predicted Values'>

# %%
m=my_model.plot_map(location = [37.5, 28.5],
                 zoom = 8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
my_model.plot_station_series()
# Out:
# <AxesSubplot:title={'center':'ET0 Measurements vs Predictions / Station: 17237'}, xlabel='Dates', ylabel='ET0 (mm/day)'>
