# %% [markdown]
# # Multiple Linear Regression (MLR) Models
# MLR models are created in this notebook using various input combinations.

# %%
import os

# %%
# %run functions\MLR_class.ipynb
# %run functions\MyModel.ipynb

# %% [markdown]
# ## Define paths:

# %% [markdown]
# Define path to the processed data directory:

# %%
# data_path = r'path\to\processed\data'

# %% [markdown]
# Define the path to the directory where the models are saved:

# %%
# save_path = r"path\to\models\directory"

# %% [markdown]
# ## Training models

# %% [markdown]
# Defining regressor and model/fit parameters

# %%
name = 'mlr'
regressor = MLRRegressor

model_params = {}
fit_params = {}

# %% [markdown]
# Training MLR models on all feature combinations

# %%
for feature_combo in range(1, 15):
    model_name = '{}_{}'.format(name, feature_combo)
    
    print('\n')
    print('Model: {}'.format(model_name))
    print('\n')
    
    my_model =  MyModel(
                    model_name=model_name,
                    feature_combo=feature_combo,
                    regressor=regressor,
                    model_params=model_params,
                    fit_params=fit_params,
                    save_path=save_path,
                    data_path=data_path
                    )
    print('\n')
    
    my_model.fit_model()
    my_model.save()
    
    print('-'*25)
# Out:
# Model: mlr_1
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_1.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.438
# RMSE = 0.546
# R2 = 0.921
# WI = 0.868
#
#
# Test scores:
# MAE = 0.431
# RMSE = 0.533
# R2 = 0.887
# WI = 0.843
# -------------------------
#
#
# Model: mlr_2
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_2.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.438
# RMSE = 0.546
# R2 = 0.921
# WI = 0.868
#
#
# Test scores:
# MAE = 0.433
# RMSE = 0.534
# R2 = 0.886
# WI = 0.842
# -------------------------
#
#
# Model: mlr_3
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_3.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.911
# RMSE = 1.150
# R2 = 0.650
# WI = 0.726
#
#
# Test scores:
# MAE = 0.781
# RMSE = 0.943
# R2 = 0.645
# WI = 0.715
# -------------------------
#
#
# Model: mlr_4
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_4.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.731
# RMSE = 0.905
# R2 = 0.783
# WI = 0.780
#
#
# Test scores:
# MAE = 0.643
# RMSE = 0.832
# R2 = 0.723
# WI = 0.765
# -------------------------
#
#
# Model: mlr_5
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_5.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.524
# RMSE = 0.650
# R2 = 0.888
# WI = 0.843
#
#
# Test scores:
# MAE = 0.511
# RMSE = 0.637
# R2 = 0.838
# WI = 0.813
# -------------------------
#
#
# Model: mlr_6
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_6.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 1.155
# RMSE = 1.387
# R2 = 0.492
# WI = 0.653
#
#
# Test scores:
# MAE = 0.914
# RMSE = 1.106
# R2 = 0.511
# WI = 0.666
# -------------------------
#
#
# Model: mlr_7
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_7.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.384
# RMSE = 0.492
# R2 = 0.936
# WI = 0.884
#
#
# Test scores:
# MAE = 0.404
# RMSE = 0.505
# R2 = 0.898
# WI = 0.853
# -------------------------
#
#
# Model: mlr_8
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_8.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.289
# RMSE = 0.397
# R2 = 0.958
# WI = 0.913
#
#
# Test scores:
# MAE = 0.334
# RMSE = 0.397
# R2 = 0.937
# WI = 0.878
# -------------------------
#
#
# Model: mlr_9
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_9.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.208
# RMSE = 0.277
# R2 = 0.980
# WI = 0.938
#
#
# Test scores:
# MAE = 0.244
# RMSE = 0.320
# R2 = 0.959
# WI = 0.911
# -------------------------
#
#
# Model: mlr_10
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_10.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.384
# RMSE = 0.491
# R2 = 0.936
# WI = 0.885
#
#
# Test scores:
# MAE = 0.403
# RMSE = 0.505
# R2 = 0.898
# WI = 0.853
# -------------------------
#
#
# Model: mlr_11
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_11.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.625
# RMSE = 0.793
# R2 = 0.834
# WI = 0.812
#
#
# Test scores:
# MAE = 0.419
# RMSE = 0.512
# R2 = 0.895
# WI = 0.847
# -------------------------
#
#
# Model: mlr_12
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_12.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.592
# RMSE = 0.758
# R2 = 0.848
# WI = 0.822
#
#
# Test scores:
# MAE = 0.382
# RMSE = 0.473
# R2 = 0.911
# WI = 0.861
# -------------------------
#
#
# Model: mlr_13
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_13.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.455
# RMSE = 0.578
# R2 = 0.912
# WI = 0.863
#
#
# Test scores:
# MAE = 0.438
# RMSE = 0.546
# R2 = 0.881
# WI = 0.840
# -------------------------
#
#
# Model: mlr_14
#
#
# Model not found at C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR\mlr_14.joblib
# MyModel object created without model
#
#
# Train scores:
# MAE = 0.593
# RMSE = 0.776
# R2 = 0.841
# WI = 0.822
#
#
# Test scores:
# MAE = 0.392
# RMSE = 0.488
# R2 = 0.905
# WI = 0.857
# -------------------------

# %% [markdown]
# ## Exploring results

# %% [markdown]
# Loading model using `MyModel`

# %%
feature_combo = 1
name = 'mlr'
model_name = '{}_{}'.format(name, feature_combo)

my_model =  MyModel(
                    model_name=model_name,
                    save_path=save_path,
                    data_path=data_path
                    )
# Out:
# mlr_1 model loaded from C:\Users\HP\Desktop\Git\evapotranspiration\part_3\MLR

# %%
my_model.plot_predictions(title='test')
plt.show()

# %%
m=my_model.plot_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ae0ccca6bf6244bea3b5f68d5758adde%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ae0ccca6bf6244bea3b5f68d5758adde%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ae0ccca6bf6244bea3b5f68d5758adde%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ae0ccca6bf6244bea3b5f68d5758adde%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5%2C%2028.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20cr ...

# %%
my_model.plot_station_series()
plt.show()
